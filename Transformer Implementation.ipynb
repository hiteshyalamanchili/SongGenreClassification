# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensor2tensor.data_generators import problem
from tensor2tensor.data_generators import text_problems
from tensor2tensor.data_generators import text_encoder
from tensor2tensor.utils import registry
import keras
from keras.engine.topology import Layer
from keras.datasets import imdb
from keras.models import Sequential, Model
from keras import backend as K
from keras.layers import *
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence, text
from keras.callbacks import ModelCheckpoint
import json
import sklearn
from sklearn import preprocessing as skpp

# %%
data = pd.read_csv('./dataset/cleaned_lyrics.csv')

# %%
genres = data['genre'].unique()
data['genre_id'] = data.groupby(['genre']).ngroup()

mappings = data[['genre', 'genre_id']].drop_duplicates()
map_list = [(genre_id, genre) for genre, genre_id in mappings.values]
map_list.sort()
map_list

data_subset = data[['genre_id', 'genre', 'lyrics']]

# %%
numpy_data = data['lyrics'].values
max_words = 30000

# create a new Tokenizer
tokenizer = text.Tokenizer(num_words=max_words, oov_token='<UNK>')
# feed our song lyrics to the Tokenizer
tokenizer.fit_on_texts(numpy_data)

# Tokenizers come with a convenient list of words and IDs
dictionary = tokenizer.word_index

with open('dictionary.json', 'w') as dictionary_file:
    json.dump(dictionary, dictionary_file)
    
tokenizer.word_index = {e:i for e,i in tokenizer.word_index.items() if i <= max_words} # <= because tokenizer is 1 indexed
tokenizer.word_index[tokenizer.oov_token] = max_words + 1
indexed_data = tokenizer.texts_to_sequences(numpy_data)
indexed_data = np.array(indexed_data)

label_encoder = skpp.LabelEncoder()
indexed_labels = np.array(label_encoder.fit_transform(data['genre'].values))
#label_encoder.inverse_transform(np.array([10, 8])) #to get original genre text back

num_test = 30000

#shuffle data before splitting off test set
random_indexes = np.random.permutation(len(indexed_labels))
indexed_data = indexed_data[random_indexes]
indexed_labels = indexed_labels[random_indexes]

X_train = indexed_data[:-num_test]
y_train = indexed_labels[:-num_test]
X_test  = indexed_data[-num_test:]
y_test  = indexed_labels[-num_test:]

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

num_words = max_words + 2
# truncate and pad input sequences
max_review_length = 600

X_train_padded = sequence.pad_sequences(X_train, maxlen=max_review_length)
X_test_padded = sequence.pad_sequences(X_test, maxlen=max_review_length)

# %%
# Implementation from https://github.com/Kyubyong/transformer/blob/master/modules.py
class PositionalEncoding(Layer):
    def __init__(self, **kwargs):
        super(PositionalEncoding,self).__init__(**kwargs)

    def build(self, input_shape):
        super(PositionalEncoding,self).build(input_shape)

    def call(self, x, mask=None):
        _, T, E = x.get_shape().as_list()
        position_ind = tf.tile(tf.expand_dims(tf.range(T), 0), [tf.shape(x)[0], 1])

        # First part of the PE function: sin and cos argument
        position_enc = np.array([
            [pos / np.power(10000, 2.*i/E) for i in range(E)]
            for pos in range(T)], dtype=np.float32)

        # Second part, apply the cosine to even columns and sin to odds.
        position_enc[:, 0::2] = np.sin(position_enc[:, 0::2])  # dim 2i
        position_enc[:, 1::2] = np.cos(position_enc[:, 1::2])  # dim 2i+1

        # Convert to a tensor
        lookup_table = tf.convert_to_tensor(position_enc)
        outputs = tf.nn.embedding_lookup(lookup_table, position_ind)
        return tf.add(outputs, x)

    def get_output_shape_for(self, input_shape):
        return input_shape
    
    def compute_output_shape(self, input_shape):
        return input_shape

def multi_head_attention(x, i, num_heads=4):
    E = embedding_vector_length
    queries = Dense(E, activation='relu')(x)
    keys = Dense(E, activation='relu')(x)
    values = Dense(E, activation='relu')(x)

    # Split and concat
    concat = lambda x: tf.concat(tf.split(x, num_heads, axis=2), axis=0)
    Q_ = Lambda(concat, name="q_reshape_{}".format(i))(queries)
    K_ = Lambda(concat, name="k_reshape_{}".format(i))(keys)
    V_ = Lambda(concat, name="v_reshape_{}".format(i))(values)

    # Multiplication
    matmul = lambda x: tf.matmul(x[0], tf.transpose(x[1], (0, 2, 1)))
    # permute_k = Permute((2, 1))(K_)
    # outputs = K.batch_dot(Q_, permute_k) # (h*N, T_q, T_k)
    outputs = Lambda(matmul, name="q_k_matmul_{}".format(i))([Q_, K_])

    # Scale
    divide = lambda x: x / (K_.get_shape().as_list()[-1] ** 0.5)
    outputs = Lambda(divide, name="divide_{}".format(i))(outputs)

    # Softmax
    softmax = lambda x: tf.nn.softmax(x)
    outputs = Lambda(softmax, name="softmax_{}".format(i))(outputs)

    # Dropouts
    outputs = Dropout(0.1)(outputs)

    # Weighted sum
    matmul2 = lambda x: tf.matmul(x[0], x[1])
    outputs = Lambda(matmul2, name="o_v_matmul_{}".format(i))([outputs, V_])

    # outputs = K.batch_dot(outputs, V_) # ( h*N, T_q, C/h)

    # Restore shape
    concat2 = lambda x: tf.concat(tf.split(x, num_heads, axis=0), axis=2)
    outputs = Lambda(concat2, name="o_reshape_{}".format(i))(outputs) # (N, T_q, C)

    return Add()([outputs, x])

# %%
embedding_vector_length = 100

inputs = Input(shape=(max_review_length,))

embeds = Embedding(num_words, embedding_vector_length, input_length=max_review_length)(inputs)
transformer_input = PositionalEncoding()(embeds)

for i in range(6):
    multi_head = multi_head_attention(transformer_input, i)
    norm = BatchNormalization()(multi_head)
    conv1 = Conv1D(400, 1, activation='relu')(norm)
    conv2 = Conv1D(100, 1)(conv1)
    res = Add()([norm, conv2])
    transformer_input = BatchNormalization()(res)

pooling = GlobalMaxPooling1D()(transformer_input)
outputs = Dense(11, activation='softmax')(pooling)
model = Model(inputs=inputs, outputs=outputs)
filepath="transformer_weights_{epoch:02d}_{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train_padded, y_train, epochs=3, batch_size=16, callbacks=[checkpoint])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 600)          0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 600, 100)     3000200     input_7[0][0]
# __________________________________________________________________________________________________
# positional_encoding_7 (Position (None, 600, 100)     0           embedding_7[0][0]
# __________________________________________________________________________________________________
# dense_115 (Dense)               (None, 600, 100)     10100       positional_encoding_7[0][0]
# __________________________________________________________________________________________________
# dense_116 (Dense)               (None, 600, 100)     10100       positional_encoding_7[0][0]
# __________________________________________________________________________________________________
# q_reshape_0 (Lambda)            (None, 600, 25)      0           dense_115[0][0]
# __________________________________________________________________________________________________
# k_reshape_0 (Lambda)            (None, 600, 25)      0           dense_116[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_0 (Lambda)           (None, 600, 600)     0           q_reshape_0[0][0]
#                                                                  k_reshape_0[0][0]
# __________________________________________________________________________________________________
# divide_0 (Lambda)               (None, 600, 600)     0           q_k_matmul_0[0][0]
# __________________________________________________________________________________________________
# softmax_0 (Lambda)              (None, 600, 600)     0           divide_0[0][0]
# __________________________________________________________________________________________________
# dense_117 (Dense)               (None, 600, 100)     10100       positional_encoding_7[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 600, 600)     0           softmax_0[0][0]
# __________________________________________________________________________________________________
# v_reshape_0 (Lambda)            (None, 600, 25)      0           dense_117[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_0 (Lambda)           (None, 600, 25)      0           dropout_37[0][0]
#                                                                  v_reshape_0[0][0]
# __________________________________________________________________________________________________
# o_reshape_0 (Lambda)            (None, 600, 100)     0           o_v_matmul_0[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 600, 100)     0           o_reshape_0[0][0]
#                                                                  positional_encoding_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 600, 100)     400         add_73[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 600, 400)     40400       batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 600, 100)     40100       conv1d_73[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 600, 100)     0           batch_normalization_73[0][0]
#                                                                  conv1d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 600, 100)     400         add_74[0][0]
# __________________________________________________________________________________________________
# dense_118 (Dense)               (None, 600, 100)     10100       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# dense_119 (Dense)               (None, 600, 100)     10100       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# q_reshape_1 (Lambda)            (None, 600, 25)      0           dense_118[0][0]
# __________________________________________________________________________________________________
# k_reshape_1 (Lambda)            (None, 600, 25)      0           dense_119[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_1 (Lambda)           (None, 600, 600)     0           q_reshape_1[0][0]
#                                                                  k_reshape_1[0][0]
# __________________________________________________________________________________________________
# divide_1 (Lambda)               (None, 600, 600)     0           q_k_matmul_1[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Lambda)              (None, 600, 600)     0           divide_1[0][0]
# __________________________________________________________________________________________________
# dense_120 (Dense)               (None, 600, 100)     10100       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 600, 600)     0           softmax_1[0][0]
# __________________________________________________________________________________________________
# v_reshape_1 (Lambda)            (None, 600, 25)      0           dense_120[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_1 (Lambda)           (None, 600, 25)      0           dropout_38[0][0]
#                                                                  v_reshape_1[0][0]
# __________________________________________________________________________________________________
# o_reshape_1 (Lambda)            (None, 600, 100)     0           o_v_matmul_1[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 600, 100)     0           o_reshape_1[0][0]
#                                                                  batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 600, 100)     400         add_75[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 600, 400)     40400       batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 600, 100)     40100       conv1d_75[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 600, 100)     0           batch_normalization_75[0][0]
#                                                                  conv1d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 600, 100)     400         add_76[0][0]
# __________________________________________________________________________________________________
# dense_121 (Dense)               (None, 600, 100)     10100       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# dense_122 (Dense)               (None, 600, 100)     10100       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# q_reshape_2 (Lambda)            (None, 600, 25)      0           dense_121[0][0]
# __________________________________________________________________________________________________
# k_reshape_2 (Lambda)            (None, 600, 25)      0           dense_122[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_2 (Lambda)           (None, 600, 600)     0           q_reshape_2[0][0]
#                                                                  k_reshape_2[0][0]
# __________________________________________________________________________________________________
# divide_2 (Lambda)               (None, 600, 600)     0           q_k_matmul_2[0][0]
# __________________________________________________________________________________________________
# softmax_2 (Lambda)              (None, 600, 600)     0           divide_2[0][0]
# __________________________________________________________________________________________________
# dense_123 (Dense)               (None, 600, 100)     10100       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 600, 600)     0           softmax_2[0][0]
# __________________________________________________________________________________________________
# v_reshape_2 (Lambda)            (None, 600, 25)      0           dense_123[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_2 (Lambda)           (None, 600, 25)      0           dropout_39[0][0]
#                                                                  v_reshape_2[0][0]
# __________________________________________________________________________________________________
# o_reshape_2 (Lambda)            (None, 600, 100)     0           o_v_matmul_2[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 600, 100)     0           o_reshape_2[0][0]
#                                                                  batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 600, 100)     400         add_77[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 600, 400)     40400       batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 600, 100)     40100       conv1d_77[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 600, 100)     0           batch_normalization_77[0][0]
#                                                                  conv1d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 600, 100)     400         add_78[0][0]
# __________________________________________________________________________________________________
# dense_124 (Dense)               (None, 600, 100)     10100       batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# dense_125 (Dense)               (None, 600, 100)     10100       batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# q_reshape_3 (Lambda)            (None, 600, 25)      0           dense_124[0][0]
# __________________________________________________________________________________________________
# k_reshape_3 (Lambda)            (None, 600, 25)      0           dense_125[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_3 (Lambda)           (None, 600, 600)     0           q_reshape_3[0][0]
#                                                                  k_reshape_3[0][0]
# __________________________________________________________________________________________________
# divide_3 (Lambda)               (None, 600, 600)     0           q_k_matmul_3[0][0]
# __________________________________________________________________________________________________
# softmax_3 (Lambda)              (None, 600, 600)     0           divide_3[0][0]
# __________________________________________________________________________________________________
# dense_126 (Dense)               (None, 600, 100)     10100       batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 600, 600)     0           softmax_3[0][0]
# __________________________________________________________________________________________________
# v_reshape_3 (Lambda)            (None, 600, 25)      0           dense_126[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_3 (Lambda)           (None, 600, 25)      0           dropout_40[0][0]
#                                                                  v_reshape_3[0][0]
# __________________________________________________________________________________________________
# o_reshape_3 (Lambda)            (None, 600, 100)     0           o_v_matmul_3[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 600, 100)     0           o_reshape_3[0][0]
#                                                                  batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 600, 100)     400         add_79[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 600, 400)     40400       batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 600, 100)     40100       conv1d_79[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 600, 100)     0           batch_normalization_79[0][0]
#                                                                  conv1d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 600, 100)     400         add_80[0][0]
# __________________________________________________________________________________________________
# dense_127 (Dense)               (None, 600, 100)     10100       batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# dense_128 (Dense)               (None, 600, 100)     10100       batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# q_reshape_4 (Lambda)            (None, 600, 25)      0           dense_127[0][0]
# __________________________________________________________________________________________________
# k_reshape_4 (Lambda)            (None, 600, 25)      0           dense_128[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_4 (Lambda)           (None, 600, 600)     0           q_reshape_4[0][0]
#                                                                  k_reshape_4[0][0]
# __________________________________________________________________________________________________
# divide_4 (Lambda)               (None, 600, 600)     0           q_k_matmul_4[0][0]
# __________________________________________________________________________________________________
# softmax_4 (Lambda)              (None, 600, 600)     0           divide_4[0][0]
# __________________________________________________________________________________________________
# dense_129 (Dense)               (None, 600, 100)     10100       batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 600, 600)     0           softmax_4[0][0]
# __________________________________________________________________________________________________
# v_reshape_4 (Lambda)            (None, 600, 25)      0           dense_129[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_4 (Lambda)           (None, 600, 25)      0           dropout_41[0][0]
#                                                                  v_reshape_4[0][0]
# __________________________________________________________________________________________________
# o_reshape_4 (Lambda)            (None, 600, 100)     0           o_v_matmul_4[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 600, 100)     0           o_reshape_4[0][0]
#                                                                  batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 600, 100)     400         add_81[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 600, 400)     40400       batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 600, 100)     40100       conv1d_81[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 600, 100)     0           batch_normalization_81[0][0]
#                                                                  conv1d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 600, 100)     400         add_82[0][0]
# __________________________________________________________________________________________________
# dense_130 (Dense)               (None, 600, 100)     10100       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# dense_131 (Dense)               (None, 600, 100)     10100       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# q_reshape_5 (Lambda)            (None, 600, 25)      0           dense_130[0][0]
# __________________________________________________________________________________________________
# k_reshape_5 (Lambda)            (None, 600, 25)      0           dense_131[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_5 (Lambda)           (None, 600, 600)     0           q_reshape_5[0][0]
#                                                                  k_reshape_5[0][0]
# __________________________________________________________________________________________________
# divide_5 (Lambda)               (None, 600, 600)     0           q_k_matmul_5[0][0]
# __________________________________________________________________________________________________
# softmax_5 (Lambda)              (None, 600, 600)     0           divide_5[0][0]
# __________________________________________________________________________________________________
# dense_132 (Dense)               (None, 600, 100)     10100       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 600, 600)     0           softmax_5[0][0]
# __________________________________________________________________________________________________
# v_reshape_5 (Lambda)            (None, 600, 25)      0           dense_132[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_5 (Lambda)           (None, 600, 25)      0           dropout_42[0][0]
#                                                                  v_reshape_5[0][0]
# __________________________________________________________________________________________________
# o_reshape_5 (Lambda)            (None, 600, 100)     0           o_v_matmul_5[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 600, 100)     0           o_reshape_5[0][0]
#                                                                  batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 600, 100)     400         add_83[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 600, 400)     40400       batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 600, 100)     40100       conv1d_83[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 600, 100)     0           batch_normalization_83[0][0]
#                                                                  conv1d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 600, 100)     400         add_84[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 100)          0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# dense_133 (Dense)               (None, 11)           1111        global_max_pooling1d_7[0][0]
# ==================================================================================================
# Total params: 3,670,911
# Trainable params: 3,668,511
# Non-trainable params: 2,400
# __________________________________________________________________________________________________
# None
# Epoch 1/3
# 197449/197449 [==============================] - 47192s 239ms/step - loss: 1.4781 - acc: 0.5334
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-ab09de61e566> in <module>()
#      21 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#      22 print(model.summary())
# ---> 23 model.fit(X_train_padded, y_train, epochs=3, batch_size=16, callbacks=[checkpoint])
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1253                             for l, o in zip(out_labels, val_outs):
#    1254                                 epoch_logs['val_' + l] = o
# -> 1255             callbacks.on_epoch_end(epoch, epoch_logs)
#    1256             if callback_model.stop_training:
#    1257                 break
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      75         logs = logs or {}
#      76         for callback in self.callbacks:
# ---> 77             callback.on_epoch_end(epoch, logs)
#      78
#      79     def on_batch_begin(self, batch, logs=None):
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     428         if self.epochs_since_last_save >= self.period:
#     429             self.epochs_since_last_save = 0
# --> 430             filepath = self.filepath.format(epoch=epoch + 1, **logs)
#     431             if self.save_best_only:
#     432                 current = logs.get(self.monitor)
#
# KeyError: 'val_acc'

# %%
# Final evaluation of the model
scores = model.evaluate(X_test_padded, y_test, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 30000/30000 [==============================] - 3553s 118ms/step
# Accuracy: 49.75%

# %%
model.save_weights('transformer-1-epoch-weights.h5')

# %%
embedding_vector_length = 100

inputs = Input(shape=(max_review_length,))

embeds = Embedding(num_words, embedding_vector_length, input_length=max_review_length)(inputs)
transformer_input = PositionalEncoding()(embeds)

for i in range(3):
    multi_head = multi_head_attention(transformer_input, i)
    norm = BatchNormalization()(multi_head)
    conv1 = Conv1D(400, 1, activation='relu')(norm)
    conv2 = Conv1D(100, 1)(conv1)
    res = Add()([norm, conv2])
    transformer_input = BatchNormalization()(res)

pooling = GlobalMaxPooling1D()(transformer_input)
outputs = Dense(11, activation='softmax')(pooling)
model2 = Model(inputs=inputs, outputs=outputs)
filepath="3_transformer_weights_{epoch:02d}_{val_acc:.2f}.hdf5"
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model2.summary())
model2.fit(X_train_padded, y_train, epochs=3, batch_size=16)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 600)          0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 600, 100)     3000200     input_9[0][0]
# __________________________________________________________________________________________________
# positional_encoding_9 (Position (None, 600, 100)     0           embedding_9[0][0]
# __________________________________________________________________________________________________
# dense_144 (Dense)               (None, 600, 100)     10100       positional_encoding_9[0][0]
# __________________________________________________________________________________________________
# dense_145 (Dense)               (None, 600, 100)     10100       positional_encoding_9[0][0]
# __________________________________________________________________________________________________
# q_reshape_0 (Lambda)            (None, 600, 25)      0           dense_144[0][0]
# __________________________________________________________________________________________________
# k_reshape_0 (Lambda)            (None, 600, 25)      0           dense_145[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_0 (Lambda)           (None, 600, 600)     0           q_reshape_0[0][0]
#                                                                  k_reshape_0[0][0]
# __________________________________________________________________________________________________
# divide_0 (Lambda)               (None, 600, 600)     0           q_k_matmul_0[0][0]
# __________________________________________________________________________________________________
# softmax_0 (Lambda)              (None, 600, 600)     0           divide_0[0][0]
# __________________________________________________________________________________________________
# dense_146 (Dense)               (None, 600, 100)     10100       positional_encoding_9[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 600, 600)     0           softmax_0[0][0]
# __________________________________________________________________________________________________
# v_reshape_0 (Lambda)            (None, 600, 25)      0           dense_146[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_0 (Lambda)           (None, 600, 25)      0           dropout_46[0][0]
#                                                                  v_reshape_0[0][0]
# __________________________________________________________________________________________________
# o_reshape_0 (Lambda)            (None, 600, 100)     0           o_v_matmul_0[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 600, 100)     0           o_reshape_0[0][0]
#                                                                  positional_encoding_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 600, 100)     400         add_91[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 600, 400)     40400       batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 600, 100)     40100       conv1d_91[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 600, 100)     0           batch_normalization_91[0][0]
#                                                                  conv1d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 600, 100)     400         add_92[0][0]
# __________________________________________________________________________________________________
# dense_147 (Dense)               (None, 600, 100)     10100       batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# dense_148 (Dense)               (None, 600, 100)     10100       batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# q_reshape_1 (Lambda)            (None, 600, 25)      0           dense_147[0][0]
# __________________________________________________________________________________________________
# k_reshape_1 (Lambda)            (None, 600, 25)      0           dense_148[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_1 (Lambda)           (None, 600, 600)     0           q_reshape_1[0][0]
#                                                                  k_reshape_1[0][0]
# __________________________________________________________________________________________________
# divide_1 (Lambda)               (None, 600, 600)     0           q_k_matmul_1[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Lambda)              (None, 600, 600)     0           divide_1[0][0]
# __________________________________________________________________________________________________
# dense_149 (Dense)               (None, 600, 100)     10100       batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 600, 600)     0           softmax_1[0][0]
# __________________________________________________________________________________________________
# v_reshape_1 (Lambda)            (None, 600, 25)      0           dense_149[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_1 (Lambda)           (None, 600, 25)      0           dropout_47[0][0]
#                                                                  v_reshape_1[0][0]
# __________________________________________________________________________________________________
# o_reshape_1 (Lambda)            (None, 600, 100)     0           o_v_matmul_1[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 600, 100)     0           o_reshape_1[0][0]
#                                                                  batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 600, 100)     400         add_93[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 600, 400)     40400       batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 600, 100)     40100       conv1d_93[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 600, 100)     0           batch_normalization_93[0][0]
#                                                                  conv1d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 600, 100)     400         add_94[0][0]
# __________________________________________________________________________________________________
# dense_150 (Dense)               (None, 600, 100)     10100       batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# dense_151 (Dense)               (None, 600, 100)     10100       batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# q_reshape_2 (Lambda)            (None, 600, 25)      0           dense_150[0][0]
# __________________________________________________________________________________________________
# k_reshape_2 (Lambda)            (None, 600, 25)      0           dense_151[0][0]
# __________________________________________________________________________________________________
# q_k_matmul_2 (Lambda)           (None, 600, 600)     0           q_reshape_2[0][0]
#                                                                  k_reshape_2[0][0]
# __________________________________________________________________________________________________
# divide_2 (Lambda)               (None, 600, 600)     0           q_k_matmul_2[0][0]
# __________________________________________________________________________________________________
# softmax_2 (Lambda)              (None, 600, 600)     0           divide_2[0][0]
# __________________________________________________________________________________________________
# dense_152 (Dense)               (None, 600, 100)     10100       batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 600, 600)     0           softmax_2[0][0]
# __________________________________________________________________________________________________
# v_reshape_2 (Lambda)            (None, 600, 25)      0           dense_152[0][0]
# __________________________________________________________________________________________________
# o_v_matmul_2 (Lambda)           (None, 600, 25)      0           dropout_48[0][0]
#                                                                  v_reshape_2[0][0]
# __________________________________________________________________________________________________
# o_reshape_2 (Lambda)            (None, 600, 100)     0           o_v_matmul_2[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 600, 100)     0           o_reshape_2[0][0]
#                                                                  batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 600, 100)     400         add_95[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 600, 400)     40400       batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 600, 100)     40100       conv1d_95[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 600, 100)     0           batch_normalization_95[0][0]
#                                                                  conv1d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 600, 100)     400         add_96[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 100)          0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# dense_153 (Dense)               (None, 11)           1111        global_max_pooling1d_9[0][0]
# ==================================================================================================
# Total params: 3,336,111
# Trainable params: 3,334,911
# Non-trainable params: 1,200
# __________________________________________________________________________________________________
# None
# Epoch 1/3
# 197449/197449 [==============================] - 23951s 121ms/step - loss: 1.3370 - acc: 0.5740
# Epoch 2/3
#   3984/197449 [..............................] - ETA: 6:35:43 - loss: 1.2455 - acc: 0.6032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-231db8aafa1a> in <module>()
#      20 model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#      21 print(model2.summary())
# ---> 22 model2.fit(X_train_padded, y_train, epochs=3, batch_size=16)
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\AppData\Local\conda\conda\envs\cs194project\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
scores2 = model2.evaluate(X_test_padded, y_test, verbose=1)
print("Accuracy: %.2f%%" % (scores2[1]*100))
# Out:
# 30000/30000 [==============================] - 1870s 62ms/step
# Accuracy: 56.18%

# %%
model2.save_weights('3-transformer-1-epoch-weights.h5')
